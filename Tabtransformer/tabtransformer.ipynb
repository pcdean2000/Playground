# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# kaggle/input/tabular-playground-series-aug-2022/sample_submission.csv
# kaggle/input/tabular-playground-series-aug-2022/test.csv
# kaggle/input/tabular-playground-series-aug-2022/train.csv

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import average_precision_score, roc_auc_score

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, KBinsDiscretizer
# Out:
# 2024-10-06 11:48:01.253640: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-06 11:48:01.257658: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-06 11:48:01.763575: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-06 11:48:02.804433: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-06 11:48:10.483064: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /mnt/e/Github/Playground/.venv/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
import absl.logging
import warnings
import logging

from tabtransformertf.models.tabtransformer import TabTransformer
from tabtransformertf.utils.preprocessing import df_to_dataset, build_categorical_prep

logging.captureWarnings(True)
warnings.filterwarnings('ignore')
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
train_data = pd.read_csv('kaggle/input/tabular-playground-series-aug-2022/train.csv').set_index('id')
test_data = pd.read_csv('kaggle/input/tabular-playground-series-aug-2022/test.csv').set_index('id')

# %%
train_data.head()
# Out:
#    product_code  loading attribute_0 attribute_1  attribute_2  attribute_3  \
# id
# 0             A    80.10  material_7  material_8            9            5
# 1             A    84.89  material_7  material_8            9            5
# 2             A    82.43  material_7  material_8            9            5
# 3             A   101.07  material_7  material_8            9            5
# 4             A   188.06  material_7  material_8            9            5
#
#     measurement_0  measurement_1  measurement_2  measurement_3  ...  \
# id                                                              ...
# 0               7              8              4         18.040  ...
# 1              14              3              3         18.213  ...
# 2              12              1              5         18.057  ...
# 3              13              2              6         17.295  ...
# 4               9              2              8         19.346  ...
#
#     measurement_9  measurement_10  measurement_11  measurement_12  \
# id
# 0          10.672          15.859          17.594          15.193
# 1          12.448          17.947          17.915          11.755
# 2          12.715          15.607             NaN          13.798
# 3          12.471          16.346          18.377          10.020
# 4          10.337          17.082          19.932          12.428
#
#     measurement_13  measurement_14  measurement_15  measurement_16  \
# id
# 0           15.029             NaN          13.034          14.684
# 1           14.732          15.425          14.395          15.631
# 2           16.711          18.631          14.094          17.946
# 3           15.250          15.562          16.154          17.172
# 4           16.182          12.760          13.153          16.412
#
#     measurement_17  failure
# id
# 0          764.100        0
# 1          682.057        0
# 2          663.376        0
# 3          826.282        0
# 4          579.885        0
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Feature Engineering

# %%
measurement_columns = [f'measurement_{i}' for i in range(18)]

# %%
from tqdm import tqdm

def convert_area(area):
    if area < 40:
        s = 'small'
    elif area < 60:
        s = 'medium'
    else:
        s = 'large'
    
    return s


train_data['area'] = train_data['attribute_2'] * train_data['attribute_3']
test_data['area'] = test_data['attribute_2'] * test_data['attribute_3']
train_data['area_label'] = train_data['area'].apply(lambda x: convert_area(x))
test_data['area_label'] = test_data['area'].apply(lambda x: convert_area(x))

train_data['avg_measurement'] = train_data[measurement_columns].mean(axis=1)
test_data['avg_measurement'] = test_data[measurement_columns].mean(axis=1)

train_data['std_measurement'] = train_data[measurement_columns].std(axis=1)
test_data['std_measurement'] = test_data[measurement_columns].std(axis=1)

# %% [markdown]
# #### Preprocessing

# %%
train_data, val_data = train_test_split(train_data, test_size=0.2, stratify=train_data['failure'])
train_data.shape, val_data.shape, test_data.shape
# Out:
# ((21256, 29), (5314, 29), (20775, 28))

# %%
train_data.columns
# Out:
# Index(['product_code', 'loading', 'attribute_0', 'attribute_1', 'attribute_2',
#        'attribute_3', 'measurement_0', 'measurement_1', 'measurement_2',
#        'measurement_3', 'measurement_4', 'measurement_5', 'measurement_6',
#        'measurement_7', 'measurement_8', 'measurement_9', 'measurement_10',
#        'measurement_11', 'measurement_12', 'measurement_13', 'measurement_14',
#        'measurement_15', 'measurement_16', 'measurement_17', 'failure', 'area',
#        'area_label', 'avg_measurement', 'std_measurement'],
#       dtype='object')

# %%
# Column information
NUMERIC_FEATURES = [ 'loading', 'area','avg_measurement','std_measurement', 'attribute_2', 'attribute_3']
NUMERIC_FEATURES += measurement_columns

CATEGORICAL_FEATURES = ['attribute_0', 'attribute_1', 'area_label']

FEATURES = list(NUMERIC_FEATURES) + list(CATEGORICAL_FEATURES)
LABEL = 'failure'

# %% [markdown]
# #### Numeric Cleaning

# %%
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()

numeric_pipe = Pipeline([
    ('impute', imputer),
    ('scale', scaler),
])

numeric_pipe.fit(train_data[NUMERIC_FEATURES])
# Out:
# Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
#                 ('scale', StandardScaler())])

# %%
train_data[NUMERIC_FEATURES] = numeric_pipe.transform(train_data[NUMERIC_FEATURES])
val_data[NUMERIC_FEATURES] = numeric_pipe.transform(val_data[NUMERIC_FEATURES])
test_data[NUMERIC_FEATURES] = numeric_pipe.transform(test_data[NUMERIC_FEATURES])

# %% [markdown]
# #### Discretising Measurements

# %%
from tqdm import tqdm
for f in tqdm(measurement_columns):
    disc = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='quantile')
    train_data[f'{f}_bined'] = disc.fit_transform(train_data[f].values.reshape(-1, 1)).astype('str')
    val_data[f'{f}_bined'] = disc.transform(val_data[f].values.reshape(-1, 1)).astype('str')
    test_data[f'{f}_bined'] = disc.transform(test_data[f].values.reshape(-1, 1)).astype('str')
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 71.16it/s]

# %% [markdown]
# #### Column Dtypes

# %%
# Column information
NUMERIC_FEATURES = [ 'loading', 'area','avg_measurement','std_measurement', 'attribute_2', 'attribute_3']

CATEGORICAL_FEATURES = [
    'attribute_0', 'attribute_1', 'area_label', 'measurement_0_bined', 
    'measurement_1_bined', 'measurement_2_bined', 'measurement_3_bined', 
    'measurement_4_bined', 'measurement_5_bined', 'measurement_6_bined',
    'measurement_7_bined', 'measurement_8_bined', 'measurement_9_bined', 
    'measurement_10_bined', 'measurement_11_bined', 'measurement_12_bined',
    'measurement_13_bined', 'measurement_14_bined', 'measurement_15_bined',
    'measurement_16_bined', 'measurement_17_bined'
]
FEATURES = NUMERIC_FEATURES + CATEGORICAL_FEATURES

# %%
# Set data types
train_data[CATEGORICAL_FEATURES] = train_data[CATEGORICAL_FEATURES].astype(str)
test_data[CATEGORICAL_FEATURES] = test_data[CATEGORICAL_FEATURES].astype(str)

train_data[NUMERIC_FEATURES] = train_data[NUMERIC_FEATURES].astype(float)
test_data[NUMERIC_FEATURES] = test_data[NUMERIC_FEATURES].astype(float)

# %%
train_data[CATEGORICAL_FEATURES]
# Out:
#       attribute_0 attribute_1 area_label measurement_0_bined  \
# id
# 25965  material_7  material_6     medium                 1.0
# 7894   material_5  material_5      large                 0.0
# 21505  material_7  material_6     medium                 1.0
# 17533  material_7  material_5      small                 4.0
# 14591  material_7  material_8     medium                 3.0
# ...           ...         ...        ...                 ...
# 16289  material_7  material_5      small                 1.0
# 17325  material_7  material_5      small                 2.0
# 20298  material_7  material_5      small                 2.0
# 2044   material_7  material_8     medium                 2.0
# 3986   material_7  material_8     medium                 1.0
#
#       measurement_1_bined measurement_2_bined measurement_3_bined  \
# id
# 25965                 2.0                 2.0                 3.0
# 7894                  1.0                 4.0                 3.0
# 21505                 4.0                 1.0                 0.0
# 17533                 4.0                 4.0                 1.0
# 14591                 1.0                 2.0                 2.0
# ...                   ...                 ...                 ...
# 16289                 2.0                 4.0                 1.0
# 17325                 4.0                 4.0                 1.0
# 20298                 1.0                 4.0                 3.0
# 2044                  2.0                 3.0                 4.0
# 3986                  0.0                 3.0                 1.0
#
#       measurement_4_bined measurement_5_bined measurement_6_bined  ...  \
# id                                                                 ...
# 25965                 2.0                 4.0                 4.0  ...
# 7894                  3.0                 1.0                 1.0  ...
# 21505                 0.0                 4.0                 4.0  ...
# 17533                 0.0                 3.0                 0.0  ...
# 14591                 2.0                 0.0                 0.0  ...
# ...                   ...                 ...                 ...  ...
# 16289                 4.0                 2.0                 1.0  ...
# 17325                 3.0                 2.0                 0.0  ...
# 20298                 1.0                 3.0                 3.0  ...
# 2044                  3.0                 3.0                 0.0  ...
# 3986                  3.0                 1.0                 0.0  ...
#
#       measurement_8_bined measurement_9_bined measurement_10_bined  \
# id
# 25965                 4.0                 1.0                  4.0
# 7894                  3.0                 2.0                  2.0
# 21505                 4.0                 2.0                  0.0
# 17533                 0.0                 0.0                  0.0
# 14591                 3.0                 2.0                  2.0
# ...                   ...                 ...                  ...
# 16289                 4.0                 0.0                  4.0
# 17325                 0.0                 4.0                  0.0
# 20298                 3.0                 2.0                  0.0
# 2044                  0.0                 4.0                  0.0
# 3986                  2.0                 2.0                  2.0
#
#       measurement_11_bined measurement_12_bined measurement_13_bined  \
# id
# 25965                  1.0                  0.0                  3.0
# 7894                   4.0                  3.0                  1.0
# 21505                  0.0                  2.0                  4.0
# 17533                  0.0                  2.0                  4.0
# 14591                  4.0                  4.0                  1.0
# ...                    ...                  ...                  ...
# 16289                  2.0                  4.0                  2.0
# 17325                  2.0                  0.0                  4.0
# 20298                  2.0                  0.0                  3.0
# 2044                   3.0                  3.0                  0.0
# 3986                   3.0                  3.0                  0.0
#
#       measurement_14_bined measurement_15_bined measurement_16_bined  \
# id
# 25965                  0.0                  1.0                  3.0
# 7894                   1.0                  0.0                  4.0
# 21505                  4.0                  2.0                  2.0
# 17533                  3.0                  1.0                  2.0
# 14591                  2.0                  3.0                  1.0
# ...                    ...                  ...                  ...
# 16289                  4.0                  2.0                  4.0
# 17325                  2.0                  0.0                  3.0
# 20298                  2.0                  0.0                  1.0
# 2044                   3.0                  2.0                  0.0
# 3986                   1.0                  4.0                  4.0
#
#       measurement_17_bined
# id
# 25965                  4.0
# 7894                   1.0
# 21505                  2.0
# 17533                  2.0
# 14591                  3.0
# ...                    ...
# 16289                  3.0
# 17325                  0.0
# 20298                  3.0
# 2044                   0.0
# 3986                   3.0
#
# [21256 rows x 21 columns]

# %% [markdown]
# #### Category Lookup Layers

# %%
category_prep_layers = build_categorical_prep(train_data, CATEGORICAL_FEATURES)
category_prep_layers
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]2024-10-06 11:48:35.495416: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.598190: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.598592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.600504: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.600739: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.600959: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.790063: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.790375: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.790390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-10-06 11:48:37.790655: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:08:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-06 11:48:37.790688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13689 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:08:00.0, compute capability: 8.9
# 100%|██████████| 21/21 [00:03<00:00,  6.42it/s]
# {'attribute_0': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f247e14b010>,
#  'attribute_1': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2511d3d2a0>,
#  'area_label': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9d690>,
#  'measurement_0_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9e200>,
#  'measurement_1_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9ca00>,
#  'measurement_2_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9de70>,
#  'measurement_3_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9e6e0>,
#  'measurement_4_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9ec80>,
#  'measurement_5_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9f220>,
#  'measurement_6_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9f7c0>,
#  'measurement_7_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2477e9fd60>,
#  'measurement_8_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccc340>,
#  'measurement_9_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccc8e0>,
#  'measurement_10_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccce80>,
#  'measurement_11_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccd420>,
#  'measurement_12_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccd9c0>,
#  'measurement_13_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccdf60>,
#  'measurement_14_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476cce530>,
#  'measurement_15_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476cceb00>,
#  'measurement_16_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccf0d0>,
#  'measurement_17_bined': <keras.src.layers.preprocessing.string_lookup.StringLookup at 0x7f2476ccf6a0>}

# %% [markdown]
# #### To TF Dataset

# %%
def df_to_dataset(
    dataframe: pd.DataFrame,
    target: str = None,
    shuffle: bool = True,
    batch_size: int = 512,
):
    df = dataframe.copy()
    if target:
        labels = df.pop(target)
        dataset = {}
        for key, value in df.items():
            dataset[key] = value.to_numpy()[:, tf.newaxis]

        dataset = tf.data.Dataset.from_tensor_slices((dict(dataset), labels))
    else:
        dataset = {}
        for key, value in df.items():
            dataset[key] = value.to_numpy()[:, tf.newaxis]

        dataset = tf.data.Dataset.from_tensor_slices(dict(dataset))

    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(dataframe))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(batch_size)
    return dataset

# %%
# PyTorch version of the above function

# import torch
# from torch.utils.data import Dataset, DataLoader

# class TabularDataset(Dataset):
#     def __init__(self, dataframe, target=None):
#         self.dataframe = dataframe.copy()
#         self.target = target
#         if target:
#             self.labels = torch.tensor(self.dataframe.pop(target).values, dtype=torch.float32)
#         self.features = {key: torch.tensor(value.values, dtype=torch.float32).unsqueeze(1) for key, value in self.dataframe.items()}

#     def __len__(self):
#         return len(self.dataframe)

#     def __getitem__(self, idx):
#         if self.target:
#             return {key: value[idx] for key, value in self.features.items()}, self.labels[idx]
#         else:
#             return {key: value[idx] for key, value in self.features.items()}

# def df_to_dataset(dataframe, target=None, shuffle=True, batch_size=512):
#     dataset = TabularDataset(dataframe, target)
#     return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

# %%
train_dataset = df_to_dataset(train_data[FEATURES + [LABEL]], LABEL, batch_size=3072)
val_dataset = df_to_dataset(val_data[FEATURES + [LABEL]], LABEL, shuffle=False, batch_size=3072)
test_dataset = df_to_dataset(test_data[FEATURES], None, shuffle=False, batch_size=3072)

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=({'loading': TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), 'area': TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), 'avg_measurement': TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), 'std_measurement': TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), 'attribute_2': TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), 'attribute_3': TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), 'attribute_0': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'attribute_1': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'area_label': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_0_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_1_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_2_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_3_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_4_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_5_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_6_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_7_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_8_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_9_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_10_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_11_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_12_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_13_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_14_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_15_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_16_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None), 'measurement_17_bined': TensorSpec(shape=(None, 1), dtype=tf.string, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# #### TabTransformer Model

# %%
for f in tqdm(measurement_columns):
    disc = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')
    train_data[f'{f}_bined'] = disc.fit_transform(train_data[f].values.reshape(-1, 1)).astype('str')
    val_data[f'{f}_bined'] = disc.transform(val_data[f].values.reshape(-1, 1)).astype('str')
    
category_prep_layers = build_categorical_prep(train_data, CATEGORICAL_FEATURES)

tabtransformer = TabTransformer(
        numerical_features = NUMERIC_FEATURES,
        categorical_features = CATEGORICAL_FEATURES,
        categorical_lookup=category_prep_layers,
        numerical_discretisers=None, # simply passing the numeric features
        embedding_dim=32,
        out_dim=1,
        out_activation='sigmoid',
        depth=6,
        heads=5,
        attn_dropout=0.087687,
        ff_dropout=0.429539,
        mlp_hidden_factors=[1, 1],
        use_column_embedding=False,
    )

LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001
NUM_EPOCHS = 1000

optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

tabtransformer.compile(
    optimizer = optimizer,
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics= [tf.keras.metrics.AUC(name="AUC", curve='ROC')],
)

early = EarlyStopping(monitor="val_loss", mode="min", patience=20, restore_best_weights=True)
callback_list = [early]

history = tabtransformer.fit(
    train_dataset, 
    epochs=NUM_EPOCHS, 
    validation_data=val_dataset,
    callbacks=callback_list,
    verbose=1,
)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# 100%|██████████| 18/18 [00:00<00:00, 131.93it/s]
# 100%|██████████| 21/21 [00:00<00:00, 269.28it/s]
# Epoch 1/1000
# 2024-10-06 11:48:46.272084: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-10-06 11:48:46.514936: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 7/7 [==============================] - 13s 360ms/step - loss: 0.8705 - AUC: 0.5023 - val_loss: 0.5808 - val_AUC: 0.5204
# Epoch 2/1000
# 7/7 [==============================] - 2s 228ms/step - loss: 0.7314 - AUC: 0.5012 - val_loss: 0.5243 - val_AUC: 0.5446
# Epoch 3/1000
# 7/7 [==============================] - 2s 227ms/step - loss: 0.6512 - AUC: 0.5195 - val_loss: 0.5206 - val_AUC: 0.5460
# Epoch 4/1000
# 7/7 [==============================] - 2s 218ms/step - loss: 0.6243 - AUC: 0.5158 - val_loss: 0.5786 - val_AUC: 0.5512
# Epoch 5/1000
# 7/7 [==============================] - 2s 223ms/step - loss: 0.6094 - AUC: 0.5151 - val_loss: 0.5233 - val_AUC: 0.5567
# Epoch 6/1000
# 7/7 [==============================] - 3s 450ms/step - loss: 0.5979 - AUC: 0.5164 - val_loss: 0.5215 - val_AUC: 0.5516
# Epoch 7/1000
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5914 - AUC: 0.5139 - val_loss: 0.5159 - val_AUC: 0.5773
# Epoch 8/1000
# 7/7 [==============================] - 2s 215ms/step - loss: 0.5804 - AUC: 0.5141 - val_loss: 0.5257 - val_AUC: 0.5666
# Epoch 9/1000
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5673 - AUC: 0.5267 - val_loss: 0.5171 - val_AUC: 0.5616
# Epoch 10/1000
# 7/7 [==============================] - 2s 216ms/step - loss: 0.5649 - AUC: 0.5267 - val_loss: 0.5189 - val_AUC: 0.5667
# Epoch 11/1000
# 7/7 [==============================] - 2s 219ms/step - loss: 0.5632 - AUC: 0.5167 - val_loss: 0.5221 - val_AUC: 0.5453
# Epoch 12/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5561 - AUC: 0.5277 - val_loss: 0.5234 - val_AUC: 0.5533
# Epoch 13/1000
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5513 - AUC: 0.5314 - val_loss: 0.5228 - val_AUC: 0.5569
# Epoch 14/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5511 - AUC: 0.5247 - val_loss: 0.5204 - val_AUC: 0.5573
# Epoch 15/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5462 - AUC: 0.5284 - val_loss: 0.5213 - val_AUC: 0.5577
# Epoch 16/1000
# 7/7 [==============================] - 2s 228ms/step - loss: 0.5431 - AUC: 0.5366 - val_loss: 0.5262 - val_AUC: 0.5551
# Epoch 17/1000
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5416 - AUC: 0.5340 - val_loss: 0.5169 - val_AUC: 0.5647
# Epoch 18/1000
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5365 - AUC: 0.5408 - val_loss: 0.5182 - val_AUC: 0.5686
# Epoch 19/1000
# 7/7 [==============================] - 2s 230ms/step - loss: 0.5345 - AUC: 0.5386 - val_loss: 0.5136 - val_AUC: 0.5722
# Epoch 20/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5328 - AUC: 0.5443 - val_loss: 0.5157 - val_AUC: 0.5668
# Epoch 21/1000
# 7/7 [==============================] - 2s 218ms/step - loss: 0.5329 - AUC: 0.5421 - val_loss: 0.5160 - val_AUC: 0.5679
# Epoch 22/1000
# 7/7 [==============================] - 2s 219ms/step - loss: 0.5313 - AUC: 0.5439 - val_loss: 0.5183 - val_AUC: 0.5680
# Epoch 23/1000
# 7/7 [==============================] - 2s 216ms/step - loss: 0.5275 - AUC: 0.5497 - val_loss: 0.5196 - val_AUC: 0.5617
# Epoch 24/1000
# 7/7 [==============================] - 2s 228ms/step - loss: 0.5288 - AUC: 0.5408 - val_loss: 0.5239 - val_AUC: 0.5568
# Epoch 25/1000
# 7/7 [==============================] - 3s 485ms/step - loss: 0.5268 - AUC: 0.5494 - val_loss: 0.5312 - val_AUC: 0.5455
# Epoch 26/1000
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5278 - AUC: 0.5431 - val_loss: 0.5269 - val_AUC: 0.5505
# Epoch 27/1000
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5251 - AUC: 0.5514 - val_loss: 0.5211 - val_AUC: 0.5663
# Epoch 28/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5252 - AUC: 0.5517 - val_loss: 0.5217 - val_AUC: 0.5541
# Epoch 29/1000
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5258 - AUC: 0.5473 - val_loss: 0.5228 - val_AUC: 0.5568
# Epoch 30/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5211 - AUC: 0.5580 - val_loss: 0.5215 - val_AUC: 0.5612
# Epoch 31/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5227 - AUC: 0.5522 - val_loss: 0.5210 - val_AUC: 0.5618
# Epoch 32/1000
# 7/7 [==============================] - 2s 216ms/step - loss: 0.5213 - AUC: 0.5571 - val_loss: 0.5179 - val_AUC: 0.5638
# Epoch 33/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5212 - AUC: 0.5598 - val_loss: 0.5178 - val_AUC: 0.5590
# Epoch 34/1000
# 7/7 [==============================] - 2s 220ms/step - loss: 0.5213 - AUC: 0.5581 - val_loss: 0.5178 - val_AUC: 0.5603
# Epoch 35/1000
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5196 - AUC: 0.5620 - val_loss: 0.5173 - val_AUC: 0.5648
# Epoch 36/1000
# 7/7 [==============================] - 2s 224ms/step - loss: 0.5193 - AUC: 0.5629 - val_loss: 0.5220 - val_AUC: 0.5551
# Epoch 37/1000
# 7/7 [==============================] - 2s 222ms/step - loss: 0.5188 - AUC: 0.5614 - val_loss: 0.5174 - val_AUC: 0.5668
# Epoch 38/1000
# 7/7 [==============================] - 2s 219ms/step - loss: 0.5189 - AUC: 0.5624 - val_loss: 0.5195 - val_AUC: 0.5650
# Epoch 39/1000
# 7/7 [==============================] - 2s 230ms/step - loss: 0.5170 - AUC: 0.5683 - val_loss: 0.5215 - val_AUC: 0.5643

# %%
val_preds = tabtransformer.predict(val_dataset)

print(f"PR AUC: {average_precision_score(val_data[LABEL], val_preds.ravel())}")
print(f"ROC AUC: {roc_auc_score(val_data[LABEL], val_preds.ravel())}")
# Out:
# 2/2 [==============================] - 1s 50ms/step
# PR AUC: 0.2569182830382546
# ROC AUC: 0.5723202803769946

# %% [markdown]
# #### Test Submission

# %%
test_preds = tabtransformer.predict(test_dataset)

submission = pd.DataFrame({
    "id": test_data.index,
    "failure": test_preds.ravel()
})

submission.to_csv("submission.csv", index=False)
# Out:
# 7/7 [==============================] - 1s 62ms/step

# %%
submission.head()
# Out:
#       id   failure
# 0  26570  0.404981
# 1  26571  0.184818
# 2  26572  0.265045
# 3  26573  0.274989
# 4  26574  0.414145

# %%
train_preds = tabtransformer.predict(train_dataset)

sns.distplot(train_preds, label='train')
sns.distplot(val_preds, label='val')
sns.distplot(submission['failure'], label='test')
plt.legend()
# Out:
# 7/7 [==============================] - 1s 70ms/step
